# %% [markdown]
# <!DOCTYPE html>
# <html lang="fa", dir="rtl">
# <body >
#     <div style="direction: rtl; unicode-bidi: embed;">
#         <h1>انواع داده‌ها در پایتون (Basic Data Types)</h1>
#         <h4>(مرور جلسه قبل)</h4>
#         <ul style="direction: ltr;">
#                 <li>int: عدد صحیح → x = 5</li>
#                 <li>float: عدد اعشاری → y = 3.14</li>
#                 <li>complex: عدد مختلط → z = 2 + 3j</li>
#                 <li>str: رشته (متن) → name = "Ali"</li>
#                 <li>bool: بولی (درست یا غلط) → flag = True یا False</li>
#         </ul>
#     </div>
# </body>
# </html>

# %%
x = 5          # int
y = 3.14       # float
z = 2 + 3j     # complex
name = "Ali"   # str
flag = True    # bool
print(type(x), type(y), type(z), type(name), type(flag))

# %% [markdown]
# <!DOCTYPE html>
# <html lang="fa", dir="rtl">
# <body >
#     <div style="direction: rtl; unicode-bidi: embed;">
#         <h1>قوانین نام‌گذاری متغیر در پایتون</h1>
#         <h4>(مرور جلسه قبل)</h4>
#         <h5>1. شروع نام متغیر</h5>
#         <ul>
#             <li>باید با حرف انگلیسی (a–z, A–Z) یا کاراکتر underscore ( _ ) شروع شود.</li>
#             <li>نمی‌تواند با عدد شروع شود.</li>
#         </ul>
#     </div>
# </body>
# </html>

# %%
age = 25      # درست
_name = "Ali" # درست
2name = "Reza" #  غلط

# %% [markdown]
# <!DOCTYPE html>
# <html lang="fa", dir="rtl">
# <body >
#     <div style="direction: rtl; unicode-bidi: embed;">
#         <h5>2. کاراکترهای مجاز</h5>
#         <ul>
#             <li>فقط می‌تواند شامل حروف انگلیسی، اعداد و underscore( _ ) باشد.</li>
#             <li>کاراکترهایی مثل فاصله، خط تیره، علامت‌ها مجاز نیستند.</li>
#         </ul>
#     </div>
# </body>
# </html>

# %%
user1 = "Sara"   # درست
user_name = "Sara" # درست
user-name = "Sara" #  غلط
user name = "Sara" #  غلط

# %% [markdown]
# <!DOCTYPE html>
# <html lang="fa", dir="rtl">
# <body >
#     <div style="direction: rtl; unicode-bidi: embed;">
#         <h5>3. حساسیت به حروف بزرگ و کوچک (Case-Sensitive)</h5>
#         <ul><li>age, Age, و AGE سه متغیر متفاوت هستند.</li></ul>
#     </div>
# </body>
# </html>

# %%
age = 20
Age = 30
AGE = 40
print(age, Age, AGE)

# %% [markdown]
# <!DOCTYPE html>
# <html lang="fa", dir="rtl">
# <body >
#     <div style="direction: rtl; unicode-bidi: embed;">
#         <h5>4. عدم استفاده از کلمات رزرو شده (Keywords)</h5>
#         <ul><li>نمی‌توان از کلمات کلیدی پایتون مثل class, def, if, else, True, False, None استفاده کرد.</li></ul>
#     </div>
# </body>
# </html>

# %%
class = "Math"  # غلط

# %% [markdown]
# <!DOCTYPE html>
# <html lang="fa", dir="rtl">
# <body>
#     <div style="direction: rtl; unicode-bidi: embed;">
#         <h5>5. طول و خوانایی </h5>
#         <ul><li>نام متغیر می‌تواند کوتاه یا بلند باشد، اما بهتر است گویا و قابل فهم باشد.</li></ul>
#     </div>
# </body>
# </html>

# %%
x = 10              # درست ولی نامفهوم
student_age = 20    # بهتر و خواناتر

# %% [markdown]
# <!DOCTYPE html>
# <html lang="fa", dir="rtl">
# <body >
#     <div style="direction: rtl; unicode-bidi: embed;">
# <h5>6. چند کلمه‌ای بودن</h5>
# <ul><li>برای متغیرهای چند کلمه‌ای از snake_case استفاده می‌شود (طبق استاندارد PEP 8).</li></ul>

# %%
student_name = "Ali"
total_volume = 100

# %% [markdown]
# <!DOCTYPE html>
# <html lang="fa", dir="rtl">
# <body >
#     <div style="direction: rtl; unicode-bidi: embed;">
#         <h5>7. کنوانسیون‌ها (Convention)</h5>
#         <ul>
#             <li>متغیرها و توابع: حروف کوچک + student_name ← underscore</li>
#             <li>ثابت‌ها (Constants): همه حروف بزرگ ← PI = 3.14</li>
#         </ul>

# %%
student_name = "Reza"
PI = 3.14

# %% [markdown]
# <!DOCTYPE html>
# <html lang="fa", dir="rtl">
# <body >
#     <div style="direction: rtl; unicode-bidi: embed;">
#         <h1>تبدیل نوع داده</h1>
#         <h4>(مرور جلسه قبل)</h4>
#         <h5>۱. تبدیل نوع ضمنی (Implicit Type Conversion)</h5>
# گاهی پایتون خودش نوع داده را تغییر می‌دهد تا عملیات درست انجام شود.<br>
# تبدیل ضمنی فقط در مواردی انجام می‌شود که پایتون مطمئن باشد داده از دست نمی‌رود (مثل int → float).

# %%
مثال:
x = 5      # int
y = 2.5    # float
z = x + y
print(z) 
print(type(z))

# %% [markdown]
# <!DOCTYPE html>
# <html lang="fa", dir="rtl">
# <body >
#     <div style="direction: rtl; unicode-bidi: embed;">
#         <h5>۲. تبدیل نوع صریح (Explicit Type Conversion)</h5>
# برنامه‌نویس می‌تواند با استفاده از توابع آماده نوع داده را تغییر دهد:
# <ul style="direction: ltr;">
#     <li>int(x) int("123") → 123</li>
#     <li>float(x) float("3.14") → 3.14</li>
#     <li>str(x) str(456) → "456"</li>
#     <li>chr(x) chr(65) → 'A'</li>
#     <li>ord(x) ord('A') → 65</li>
# </ul>

# %%
num = int("123")
print(num + 10) 
print(int('abc'))

# %%
age = 20
text = "I'm " + str(age) + " years old."
print(text)

# %%
print(ord('A'))
print(chr(65))

# %% [markdown]
# <!DOCTYPE html>
# <html lang="fa", dir="rtl">
# <body >
#     <div style="direction: rtl; unicode-bidi: embed;">
#         <h1>تقدم عملگرها در پایتون (PEMDAS)</h1>
#         <h4>(مرور جلسه قبل)</h4>
# در پایتون، ترتیب اجرای عملگرها (Precedence) طبق قانون PEMDAS است: پرانتز ← توان ← ضرب و تقسیم ← جمع و تفریق.<br>
# اگر چند عملگر در یک عبارت باشند، پایتون آن‌ها را بر اساس این تقدم اجرا می‌کند.
# <h5>قانون PEMDAS</h5>
# <ul>
#     <li>P (Parentheses) → پرانتزها اول اجرا می‌شوند.</li>
#     <li>E (Exponentiation) → توان (**) بعد از پرانتز.</li>
#     <li>M (Multiplication) → ضرب (*) بعد از توان</li>
#     <li>D (Division) → تقسیم (/)، تقسیم صحیح (//)، باقیمانده (%)</li>
#     <li>A (Addition) → جمع (+)</li>
#     <li>S (Subtraction) → تفریق (-).</li>
# </ul>

# %%
result = 10 - 2 * 3 ** 2 / 2
print(result)

# %% [markdown]
# <!DOCTYPE html>
# <html lang="fa", dir="rtl">
# <body >
#     <div style="direction: rtl; unicode-bidi: embed;">
#         <h1>متغیر پویا در پایتون (Dynamic Variable)</h1>
# در زبان‌های برنامه‌نویسی مثل C یا Java باید نوع متغیر را از قبل مشخص کنیم (مثلاً int age = 20).<br>
# اما در پایتون کافی است یک مقدار به متغیر بدهیم؛ پایتون خودش نوع داده را تشخیص می‌دهد.

# %%
x = 5        # نوع: int
x = 3.14     # نوع: float
x = "Ali"    # نوع: str

# %% [markdown]
# <!DOCTYPE html>
# <html lang="fa", dir="rtl">
# <body >
#     <div style="direction: rtl; unicode-bidi: embed;">
#     همان متغیر x می‌تواند در طول برنامه نوع‌های مختلف داشته باشد.<br>
# 🔹 چرا پویا بودن مهم است؟<br>
# - سادگی: نیازی به تعریف نوع داده نیست.<br>
# - انعطاف‌پذیری: می‌توانیم یک متغیر را دوباره با نوع دیگری استفاده کنیم.<br>
# - سرعت توسعه: برای برنامه‌نویسان راحت‌تر است.<br>

# %%
data = 10
print(data, type(data))

data = 10.5
print(data, type(data))

data = "hello!"
print(data, type(data))

# %% [markdown]
# <!DOCTYPE html>
# <html lang="fa", dir="rtl">
# <body >
#     <div style="direction: rtl; unicode-bidi: embed;">
#         <h1>عملگرهای بیتی در پایتون</h1>
#         کامپیوتر همه چیز را با صفر و یک ذخیره می‌کند. هر عدد صحیح در حافظه به شکل دودویی (binary) نمایش داده می‌شود. عملگرهای بیتی به شما اجازه می‌دهند مستقیماً روی این صفر و یک‌ها عملیات انجام دهید.

# %%
print(bin(5))
print(bin(3))

# %% [markdown]
# <!DOCTYPE html>
# <html lang="fa", dir="rtl">
# <body >
#     <div style="direction: rtl; unicode-bidi: embed;">
#
#
# <ul>
#     <li><h4>عملگر AND (&)</h4></li>
#     <li>هر بیت را مقایسه می‌کند: اگر هر دو بیت 1 باشند، نتیجه 1 می‌شود، در غیر این صورت 0.</li>
# </ul>

# %%
a = 5   # 0101
b = 3   # 0011
print(a & b)

# %% [markdown]
# <!DOCTYPE html>
# <html lang="fa", dir="rtl">
# <body >
#     <div style="direction: rtl; unicode-bidi: embed;">
# <ul>
#     <li><h4>عملگر OR (|)</h4></li>
#     <li>اگر یکی از بیت‌ها 1 باشد، نتیجه 1 می‌شود.</li>
# </ul>

# %%
a = 5   # 0101
b = 3   # 0011
print(a | b)

# %% [markdown]
# <!DOCTYPE html>
# <html lang="fa", dir="rtl">
# <body >
#     <div style="direction: rtl; unicode-bidi: embed;">
# <ul>
#     <li><h4>عملگر XOR (^)</h4></li>
#     <li>اگر بیت‌ها متفاوت باشند (یکی 0 و دیگری 1)، نتیجه 1 می‌شود.</li>
# </ul>

# %%
a = 5   # 0101
b = 3   # 0011
print(a ^ b)

# %% [markdown]
# <!DOCTYPE html>
# <html lang="fa", dir="rtl">
# <body >
#     <div style="direction: rtl; unicode-bidi: embed;">
# <ul>
#     <li><h4>عملگر NOT (~)</h4></li>
#     <li>تمام بیت‌ها را برعکس می‌کند. در پایتون این عملگر برابر با -(عدد+1) است.</li>
# </ul>

# %%
a = 5   # 0101
print(~a)

# %% [markdown]
# <!DOCTYPE html>
# <html lang="fa", dir="rtl">
# <body >
#     <div style="direction: rtl; unicode-bidi: embed;">
# <ul>
#     <li><h4>شیفت به چپ (<<)</h4></li>
#     <li>بیت‌ها را به سمت چپ حرکت می‌دهد و صفر اضافه می‌کند. معادل ضرب در توان‌های 2 است.</li>
# </ul>

# %%
a = 5   # 0101
print(a << 1)
print(a << 2)

# %% [markdown]
# <!DOCTYPE html>
# <html lang="fa", dir="rtl">
# <body >
#     <div style="direction: rtl; unicode-bidi: embed;">
# <ul>
#     <li><h4>شیفت به راست (>>)</h4></li>
#     <li>بیت‌ها را به سمت راست حرکت می‌دهد. معادل تقسیم صحیح بر توان‌های 2 است.</li>
# </ul>

# %%
a = 5   # 0101
print(a >> 1)
print(a >> 2)

# %% [markdown]
# <!DOCTYPE html>
# <html lang="fa", dir="rtl">
# <body >
#     <div style="direction: ltr; unicode-bidi: embed;">
# <ul>
#     <li><h4>تقدم عملگرها(  ترتیب اجرا در پایتون مهم است)</h4></li>
#     <li>~ (NOT)</li>
#     <li><<, >> (SHIFT)</li>
#     <li>& (AND)</li>
#     <li>^ (XOR)</li>
#     <li>| (OR)</li>
# </ul>

# %%
a = 6   # 0110
b = 3   # 0011
result = ~a & b ^ a | b << 1 >> 1
print(result)

# %% [markdown]
# <!DOCTYPE html>
# <html lang="fa", dir="rtl">
# <body >
#     <div style="direction: rtl; unicode-bidi: embed;">
#         <h1>List, Tuple, Set, Dict</h1>
# <h2>۱. لیست (List)</h2>
#     <ul>
#         <li><h3>ویژگی‌ها:</h3></li>
#         <li>قابل تغییر (Mutable)</li>
#         <li>مرتب (Ordered)</li>
#         <li>می‌تواند عناصر تکراری داشته باشد</li>
#     </ul>

# %%
my_list = [1, 2, 3, 4]

# %% [markdown]
# <!DOCTYPE html>
# <html lang="fa", dir="rtl">
# <body >
#     <div style="direction: rtl; unicode-bidi: embed;">
#     <ul>
#         <li><h3>متد های اصلی:</h3></li>
#     </ul>

# %%
my_list.append(5)   # اضافه کردن
my_list.remove(2)   # حذف کردن
my_list.pop()       # حذف آخرین عنصر
my_list.sort()      # مرتب‌سازی
my_list.reverse()   # برعکس کردن

# %% [markdown]
# <!DOCTYPE html>
# <html lang="fa", dir="rtl">
# <body >
#     <div style="direction: rtl; unicode-bidi: embed;">
# <h2>۲. تاپل (Tuple)</h2>
#     <ul>
#         <li><h3>ویژگی‌ها:</h3></li>
#         <li>غیرقابل تغییر (Immutable)</li>
#         <li>مرتب (Ordered)</li>
#         <li>می‌تواند عناصر تکراری داشته باشد</li>
#     </ul>

# %%
my_tuple = (1, 2, 3)

# %% [markdown]
# <!DOCTYPE html>
# <html lang="fa", dir="rtl">
# <body >
#     <div style="direction: rtl; unicode-bidi: embed;">
#     <ul>
#         <li><h3>متد های اصلی:</h3></li>
#     </ul>
#     چون تاپل تغییرناپذیر است، متدهای آن محدود هستند.

# %%
print(my_tuple.count(2))   # تعداد تکرار یک عنصر
print(my_tuple.index(3))   # موقعیت عنصر

# %% [markdown]
# <!DOCTYPE html>
# <html lang="fa", dir="rtl">
# <body >
#     <div style="direction: rtl; unicode-bidi: embed;">
# <h2>۳. مجموعه (Set)</h2>
#     <ul>
#         <li><h3>ویژگی‌ها:</h3></li>
#         <li>قابل تغییر (Mutable)</li>
#         <li>غیرمرتب (Unordered)</li>
#         <li>عناصر یکتا (بدون تکرار)</li>
#     </ul>

# %%
my_set = {1, 2, 3, 3}
print(my_set)

# %% [markdown]
# <!DOCTYPE html>
# <html lang="fa", dir="rtl">
# <body >
#     <div style="direction: rtl; unicode-bidi: embed;">
#     <ul>
#         <li><h3>متد های اصلی:</h3></li>
#     </ul>

# %%
my_set.add(4)       # اضافه کردن
my_set.remove(2)    # حذف کردن
my_set.union({5, 6}))       # اجتماع
my_set.intersection({2, 3}) # اشتراک
my_set.difference({2})     # تفاضل

# %% [markdown]
# <!DOCTYPE html>
# <html lang="fa", dir="rtl">
# <body >
#     <div style="direction: rtl; unicode-bidi: embed;">
# <h2>۴. دیکشنری (Dict)</h2>
#     <ul>
#         <li><h3>ویژگی‌ها:</h3></li>
#         <li>قابل تغییر (Mutable)</li>
#         <li>داده‌ها به صورت کلید–مقدار ذخیره می‌شوند.</li>
#         <li>کلیدها یکتا هستند.</li>
#     </ul>

# %%
my_dict = {"name": "Ali", "age": 20}

# %% [markdown]
# <!DOCTYPE html>
# <html lang="fa", dir="rtl">
# <body >
#     <div style="direction: rtl; unicode-bidi: embed;">
#     <ul>
#         <li><h3>متد های اصلی:</h3></li>
#     </ul>

# %%
my_dict["name"]    # دسترسی به مقدار
my_dict["city"] = "Tehran" # اضافه کردن کلید جدید
my_dict.pop("age")        # حذف کلید
my_dict.keys()     # لیست کلیدها
my_dict.values()   # لیست مقادیر
my_dict.items()    # کلید–مقدارها

# %% [markdown]
# <!DOCTYPE html>
# <html lang="fa", dir="rtl">
# <body >
#     <div style="direction: rtl; unicode-bidi: embed;">
#         <h1>Escape Sequences در پایتون (کاراکترهای گریز)</h1>
# کاراکترهای گریز برای نمایش کاراکترهایی استفاده می‌شوند که به طور مستقیم نمی‌توان در رشته نوشت.<br>
# همیشه با بک‌اسلش (\) شروع می‌شوند.<br>
# مثال: اگر بخواهیم داخل یک رشته از علامت نقل قول " " استفاده کنیم، باید از \" استفاده کنیم.<br>
#     <ul>
#         <li><h3>پرکاربردترین Escape Sequences</h3></li>
#         <li>\n خط جدید</li>
#         <li>\t تب </li>
#         <li>\\ بک اسلش|</li>
#         <li>\" کوتیشن دوتایی</li>
#         <li>\' کوتیشن تکی </li>
#         <li>\r بازگشت به اول خط </li>
#         <li>\b بک اسپیس(حذف کاراکتر قبل) </li>
#         <li>\uXXXX نمایش کاراکتر unicode</li>
#     </ul>

# %%
print("Hello\nWorld")
print("Hello\tWorld")
print("C:\\Users")
print("He said: \"Hi\"")
print('It\'s ok')
print("Hello\rWorld")
print("Helloo\b")
print("\u0627")

# %% [markdown]
# <!DOCTYPE html>
# <html lang="fa", dir="rtl">
# <body >
#     <div style="direction: rtl; unicode-bidi: embed;">
#         <h1 style="direction: rtl; unicode-bidi: embed;">توابع در پایتون</h1>
#     توابع به عنوان یکی از مفاهیم اساسی زبان های برنامه نویسی، دارای  مزایای بسیاری هستند.با استفاده از توابع میتوان مجموعه دستوراتی که مکرراً اجرا میشوند را مدیریت کرد.
#     </div>
# </body>
# </html>

# %% [markdown]
# <!DOCTYPE html>
# <html lang="fa", dir="rtl">
# <body >
#     <div style="direction: rtl; unicode-bidi: embed;">
#     <h3 style="direction: rtl; unicode-bidi: embed;">فراخوانی تابع</h3>
#     در جلسه قبل شما با توابعی مثل ()print یا ()type آشنا شدید. فرم کلی فراخوانی توابع همواره به همین شکل است:
#         <ul">
#             <li>نوشتن نام تابع</li>
#             <li>نوشتن آرگومان های تابع درون پرانتز در جلوی آن</li>
#         </ul>
#     </div>
# </body>
# </html>

# %%
print("hello python") # "hello python" is the argument
type(3.14)   # 3.14 is the argument

# %% [markdown]
# <!DOCTYPE html>
# <html lang="fa", dir="rtl">
# <body>
#     <div style="direction: rtl; unicode-bidi: embed;">
#     <h3>مقدار برگشتی تابع</h3>
#         توابع میتوانند به دو صورت رفتار کنند:
#     <ul>
#         <li>صرفا عملیات خاصی را انجام دهند مثل ()print</li>
#         <li>محاسبات و عملیاتی را روی آرگومان های خود انجام دهد و نتیجه را برگرداند مثل ()type</li>
#     </ul>
#     </p>
#     </div>
# </body>
# </html>

# %%
print_return = print("hello python")   # save return value of print func
type_return = type(1j)   # save return value of type func

# %%
print_return # this is print nothing!

# %%
type_return   # this is print complex!

# %% [markdown]
# <!DOCTYPE html>
# <html lang="fa", dir="rtl">
# <body>
#     <div style="direction: rtl; unicode-bidi: embed;">
#     <h3>تابع input()</h3>
#         برای تعریف تابع از کلمه کلیدی def استفاده میکنیم:<br>
#         تابع input() برای گرفن ورودی از کاربر استفاده میشود.<br>
#         این تابع یک str به عنوان آرگومان میگیرد که قبل از دریافت از کاربر نمایش میدهد<br>
#         <b>مقدار بازگشتی این تابع همواره به صورت str است پس اگر قرار باشد از کاربر مقدار عددی دریافت شود، باید از تابع ()int یا تابع ()float نیز استفاده شود.</b>
#     </div>
# </body>
# </html>

# %%
age = input("enter your age:")
print(type(age))

# %%
age = float(input("enter your age:"))
print(type(age))

# %% [markdown]
# <!DOCTYPE html>
# <html lang="fa", dir="rtl">
# <body>
#     <div style="direction: rtl; unicode-bidi: embed;">
#     <h3>تعریف تابع</h3>
#         برای تعریف تابع از کلمه کلیدی def استفاده میکنیم:<br>
#         کد های توابع باید در یک بلوک نوشته شوند.<br>
#         پایتون بر خلاف زبان هایی مثل c یا java که از {} برای تعریف بلوک استفاده میکندد، از تورفتگی(Indentation) استفاده میکند.<br>
#         پس تمامی کدهای تابع بایستی با فاصله برابر نسبت به تعریف تابع تورفتگی داشته باشند.<br>
#         این فاصله در اکثر IDE  ها به صورت tab = 4 space تعریف میشود اما میتوان آن را تغییر داد به شرط آنکه تمام بلوک از آن پیروی کند.
#     </div>
# </body>
# </html>

# %%
def hello ():
    print("this is hello from hello function")

# %% [markdown]
# <!DOCTYPE html>
# <html lang="fa", dir="rtl">
# <body>
#     <div style="direction: rtl; unicode-bidi: embed;">
#         تابع بالا اکنون هیچ کاری انجام نمیدهد چون فراخوانی نشده است.
#     </div>
# </body>
# </html>

# %%
hello()   # call hello function

# %% [markdown]
# <!DOCTYPE html>
# <html lang="fa", dir="rtl">
# <body>
#     <div style="direction: rtl; unicode-bidi: embed;">
#     <h3>تعریف پارامتر تابع</h3>
#         برای ارسال آرگومان به تابع نیاز است در تعریف تابع پارامتر های آن را مشخص کنیم.<br>
#         به طور دقیق تر وقتی تابعی فراخوانی میشود پارامتر های آن با آرگومان های ارسالی پر میشود.
#     </div>
# </body>
# </html>

# %%
def greeting(name):
    print("hello" , name)

# %% [markdown]
# <!DOCTYPE html>
# <html lang="fa", dir="rtl">
# <body>
#     <div style="direction: rtl; unicode-bidi: embed;">
#         پارامتر های تابع، متغیر هایی هستند که صرفا در بلوک تابع معتبرند یعنی خارج از آن معتبر نیستند
#     </div>
# </body>
# </html>

# %%
def power_of_two(number):
    print(number**2)

# %%
power_of_two(8)
print(number)

# %% [markdown]
# <!DOCTYPE html>
# <html lang="fa", dir="rtl">
# <body>
#     <div style="direction: rtl; unicode-bidi: embed;">
#         میتوان در تعریف پارامتر، نوع آن را نیز مشخص کرد.
#     </div>
# </body>
# </html>

# %%
def sum(a: int, b: int):
    print("the sum is:" , a + b)

# %%
sum(1, 2)

# %% [markdown]
# <!DOCTYPE html>
# <html lang="fa", dir="rtl">
# <body>
#     <div style="direction: rtl; unicode-bidi: embed;">
#         اما اگر نوع دیگری از داده برای تابع ارسال شود پاسخ تابع چیست؟
#     </div>
# </body>

# %%
sum(1, 2.3)

# %% [markdown]
# <!DOCTYPE html>
# <html lang="fa", dir="rtl">
# <body>
#     <div style="direction: rtl; unicode-bidi: embed;">
#         پایتون زبانی پویاست و برخلاف اکثر زبان های برنامه نویسی میتواند نوع داده متغیر هارا تغییر دهد پس ارسال آرگومانی با نوع متفاوت از پارامتر تابع مشکلی ایجاد نمیکد.<br>
#         در آینده در مبحث مدیریت خطا در پایتون می آموزیم که چگونه ارسال داده اشتباه به تابع را مدیریت کنیم
#         <h3>مقدار برگشتی تابع</h3>
#         در تعریف توابع با استفاده از کلمه کلیدی return میتوان مقدار برگشتی تابع را تنظیم کرد.
#     </div>
# </body>

# %%
def minus(a , b):
    return a - b

# %%
print(minus(5, 2))

# %%
x = None
print(type(x))

# %% [markdown]
# <!DOCTYPE html>
# <html lang="fa", dir="rtl">
# <body >
#     <div style="direction: rtl; unicode-bidi: embed;">
#     <ul>
#         <li><h3>ویژگی‌ها:</h3></li>
#         <li>فقط یک مقدار دارد: None</li>
#         <li>برای نشان دادن خالی بودن یا نبود مقدار استفاده می‌شود.</li>
#         <li>خودش یک شیء (Object) است و می‌توان آن را به متغیرها نسبت داد.</li>
#     </ul>
#     <ul>
#         <li><h3>کاربردهای رایج</h3></li>
#         <li>مقدار پیش‌فرض در توابع</li>
#         <li>اگر تابعی چیزی برنگرداند، خروجی آن None خواهد بود:</li>
#     </ul>

# %%
def test():
    pass

print(test())

# %% [markdown]
# <!DOCTYPE html>
# <html lang="fa", dir="rtl">
# <body >
#     <div style="direction: rtl; unicode-bidi: embed;">
#         <h3>افزودن ماژول</h3>
#         برای مدیریت ماژول ها سه کلمه کلیدی وجود دارد
#         <ul">
#             <li>import</li>
#             <li>from</li>
#             <li>as</li>
#         </ul>
#     </div>
# </body>
# </html>

# %%
import math   # افزودن ماژول به صورت کامل
from math import sin  # افزودن تابع سینوس از ماژول
import math as riazi  # افزودن ماژول با نامگذاری مجدد در کد خود

# %% [markdown]
# <!DOCTYPE html>
# <html lang="fa", dir="rtl">
# <body >
#     <div style="direction: rtl; unicode-bidi: embed;">
#         برای استفاده از توابع ماژول ها باید بعد از اسم ماژول، اسم تابع را استفاده کنیم
#     </div>
# </body>
# </html>

# %%
math.sinh(12)
riazi.sinh(12)

# %% [markdown]
# <!DOCTYPE html>
# <html lang="fa", dir="rtl">
# <body >
#     <div style="direction: rtl; unicode-bidi: embed;">
#         اگر فقط بخشی از ماژول را اضافه کرده باشیم، نیازی به بردن اسم ماژول نیست و فقط اسم تابع را استفاده میکنیم.<br>
#         برای اینکه چند تابع را از یک ماژول اضافه کنیم میتوانیم بعد از import اسم تمام تابع های مورد نیاز را بیاوریم و با , از هم جدا کنیم.<br>
#         همچنین میتوان با * تمامی توابع یک ماژول را اضافه کرد.
#             </div>
# </body>
# </html>

# %%
from math import sinh
sinh(11)

# %%
from math import tan, tanh
tanh(33)

# %%
from math import *
sqrt(14)

# %% [markdown]
# <!DOCTYPE html>
# <html lang="fa", dir="rtl">
# <body >
#     <div style="direction: rtl; unicode-bidi: embed;">
#         در ادامه بیشتر با بحث ماژول ها و نحوه ساخت آنها آشنا میشویم.<br>
#     </div>
# </body>
# </html>

# %% [markdown]
# <!DOCTYPE html>
# <html lang="fa", dir="rtl">
# <body >
#     <div style="direction: rtl; unicode-bidi: embed;">
#         <h1>عبارات شرطی</h1>
#         در جلسه قبل با گزاره های منطقی و متغیر های boolean آشنا شدیم. اکنون با استفاده از آنها به بررسی ساختار شرطی در پایتون میپردازیم
#     </div>
# </body>
# </html>

# %%
a = True
b = False
c = a == b
d = a > b

# %% [markdown]
# <!DOCTYPE html>
# <html lang="fa", dir="rtl">
# <body >
#     <div style="direction: rtl; unicode-bidi: embed;">
#         <ul>
#             <li><h3>یادآوری: عملگر های منطقی</h3></li>
#             <li> == تساوی</li>
#             <li>!= نامساوی</li>
#             <li>> کوچکتر</li>
#             <li>>= کوچتر مساوی</li>
#             <li>< بزرگتر</li>
#             <li><= بزرگتر مساوی</li>
#             <li>and و ی منطقی</li>
#             <li>or یا ی منطقی</li>
#             <li>not نقیض منطقی</li>
#     </div>
# </body>
# </html>

# %%
a, b, c, d = 5, 6, True, False
print(a == b)
print(a != b)
print(a < b)
print(a <= b)
print(a > b)
print(a >= b)
print(c and d)
print(c or d)
print(not c)

# %% [markdown]
# <!DOCTYPE html>
# <html lang="fa", dir="rtl">
# <body >
#     <div style="direction: rtl; unicode-bidi: embed;">
#         <h3>ساختار شرطی if</h3>
#         بلوک if یک شرط منطقی را بررسی میکند و با درست بودن شرط، کد های درون بلوک را اجرا میکند. در صورت غلط بودن شرط هیچکدام از دستورات داخل بلوک اجرا نمیشوند.
#     </div>
# </body>
# </html>

# %%
if c and d:
    print("this is a false condition so this message won't be print!")

if c or d :
    print("this is a true condition and this message will be print!")

# %% [markdown]
# <!DOCTYPE html>
# <html lang="fa", dir="rtl">
# <body >
#     <div style="direction: rtl; unicode-bidi: embed;">
#         if یک کلمه کلیدی پایتون است و قابل استفاده در نامگذاری ها نمیباشد.<br>
#         ساختار های پیچیده تر شرطی با کلمات کلیدی زیر ساخته میشود:<br>
#         <ul>
#             <li><b>elif:</b> حتما بعد از if می آید و مانند if است؛ با این تفاوت که در صورت درست بودن شرط خود if شرط elif بررسی نمیشود.</li>
#             <li><b>else:</b> بعد از if و elif می آید و در صورت غلط بودن تمامی if ها و elif ها بلوک else اجرا میشود.</li>
#         </ul>
#     </div>
# </body>
# </html>

# %%
a = 5
b = 7
if a > b:
    print("a bigger than b")
elif a < b:
    print("a smaller than b")
else:
    print("a is equal b")

# %% [markdown]
# <!DOCTYPE html>
# <html lang="fa", dir="rtl">
# <body >
#     <div style="direction: rtl; unicode-bidi: embed;">
#         <h3>ساختار های شرطی تو در تو:</h3>
#         می توان ساختار های شرطی را به صورت تو در تو پیاده کرد به صورتی که ابتدا شرط لایه بیرونی بررسی میشود و در صورت صحیح بودن به لایه داخلی میرود.
#     </div>
# </body>
# </html>

# %%
first_number = 120
second_number = -10

if first_number > 100:
    print("wow! a big number")
    if second_number > 0 :
        print("so lucky! this is positive")
    elif second_number == 0:
        print("not bad! it's zero")
    else:
        print("It's bad! negative :(")
elif first_number > 0:
    print("not bad! still positive!!")
    if second_number > 0:
        print("wow! this is positive too!")
    elif second_number == 0:
        print("it's bad! zero :/ ")
    else:
        print("It's awful! negative :(")
else:
    print("bad luck..... it's negative :|")

# %% [markdown]
# <!DOCTYPE html>
# <html lang="fa", dir="rtl">
# <body >
#     <div style="direction: rtl; unicode-bidi: embed;">
#         <h3>ساخار شرطی درون تابع</h3>
#         در توابع میتوان با شرط if دو مقدار بازگشتی متفاوت را تولید کرد
#     </div>
# </body>
# </html>
